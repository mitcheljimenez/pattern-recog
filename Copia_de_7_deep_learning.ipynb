# %% [markdown]
# <a href="https://colab.research.google.com/github/mitcheljimenez/pattern-recog/blob/main/Copia_de_7_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning: Segmentación de imágenes

# %% [markdown]
# Deep learning es un tipo de aprendizaje de máquinas en donde las predicciones se realizan a través de una serie de operaciones matriciales concatenadas. Uno de los elementos más importantes en el Deep Learning es la casi nula ingeniería de características. En el ejemplo que veremos ahora, se utiliza un conjunto de imágenes segmentadas para realizar el entrenamiento de un modelo de segmentación automática de núcleos celulares, este entrenamiento simplemente se realiza con los pixeles crudos de las imágenes, sin ingeniería de características.

# %%
# Importamos todos los paquetes y módulos para entrenar el modelo

import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras import layers
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers import concatenate
from keras.utils import image_dataset_from_directory
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# %% [markdown]
# Google Colab nos ofrece poder utilizar GPUs (Graphical Processing Units) para realizar el entrenamiento. La utilización de este hardware nos facilita un entrenamiento muy significativamente más rápido que el entrenamiento en CPU.

# %%
tf.test.gpu_device_name() # Verificamos que Tensorflow está utilizando una GPU
# Out:
# '/device:GPU:0'

# %% [markdown]
# ## Clasificación Inception V3

# %%
#Descargamos la Base de Datos, una versión mini de ImageNet 
# !gdown 1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc -O cats.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aNRd1WZT7s4vIXy3mGgLsMQI1N9B6qrc
# To: /content/cats.zip
# 100% 129M/129M [00:03<00:00, 32.9MB/s]

# %%
#Unzip BD
# !unzip -q cats.zip -d cats/

# %%
from tensorflow.keras.applications import InceptionV3

#Base Model
pre_trained_model = InceptionV3(
    input_shape=(299, 299, 3), include_top=True, weights="imagenet")

#Base model por transfer
pre_trained_model_transfer = InceptionV3(
    input_shape=(224, 224, 3), include_top=False, weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %%
#Flatten a una capa de 1 dimensión
x = layers.Flatten()(pre_trained_model_transfer.output)
#Se añade una capa Fully-Connected
x = layers.Dense(1024, activation="relu")(x)
#Se añade una capa de Dropout
x = layers.Dropout(0.2)(x)
#Capa final de clasificación
x = layers.Dense(10, activation="softmax")(x)

model = Model(pre_trained_model_transfer.input, x)

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from PIL import Image

img_size = (224, 224)

def plot_images(folder):
    subfolders = [f.path for f in os.scandir(folder) if f.is_dir()]
    fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(12, 6))
    for i, subfolder in enumerate(subfolders):
        filenames = os.listdir(subfolder)
        image_path = os.path.join(subfolder, filenames[4])
        image = Image.open(image_path)
        imgae = image.resize(img_size)
        ax = axes[i // 5, i % 5]
        ax.imshow(image)
        ax.set_title(os.path.basename(subfolder))
        ax.axis("off")

plot_images("/content/cats/train")

# %%
#Cargar Cats
#Data Augmentation 
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255) # A las imágenes se les normaliza el brillo

train_datagen_aug = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                                shear_range = 0.2, # Distorsionamos las imágenes
                                                                zoom_range = 0.2, # Acercamos las imágenes
                                                                horizontal_flip = True,
                                                                vertical_flip=True) # Volteamos horizontalmente las imágenes

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)                                  

#Entrenamiento
train_cat = train_datagen.flow_from_directory('/content/cats/train',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Entrenamiento Data Augmentation
train_cat_aug = train_datagen_aug.flow_from_directory('/content/cats/train',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Validación
val_cat = test_datagen.flow_from_directory('/content/cats/valid',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')

#Test
test_cat = test_datagen.flow_from_directory('/content/cats/test',
                                              target_size = img_size, # Las imágenes se redimensionan a 64*64
                                              batch_size = 16,
                                              class_mode = 'categorical')
# Out:
# Found 2339 images belonging to 10 classes.
# Found 2339 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.
# Found 50 images belonging to 10 classes.

# %%
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
def get_callbacks():
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1)
    checkpoint = ModelCheckpoint('cats.hdf5',verbose=1, save_best_only= True)
    early_stop = EarlyStopping(monitor='val_loss', patience=5, verbose=1, restore_best_weights=True)
    return [reduce_lr, checkpoint, early_stop]

hist = model.fit(train_cat,
          epochs = 30,
          validation_data = val_cat,
          callbacks=get_callbacks())
# Out:
# Epoch 1/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.3343
# Epoch 1: val_loss improved from inf to 12.29984, saving model to cats.hdf5
# 147/147 [==============================] - 32s 219ms/step - loss: 0.2495 - accuracy: 0.3343 - val_loss: 12.2998 - val_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.3608
# Epoch 2: val_loss improved from 12.29984 to 2.39440, saving model to cats.hdf5
# 147/147 [==============================] - 29s 196ms/step - loss: 0.2445 - accuracy: 0.3608 - val_loss: 2.3944 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 3/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.3634
# Epoch 3: val_loss improved from 2.39440 to 0.24267, saving model to cats.hdf5
# 147/147 [==============================] - 27s 185ms/step - loss: 0.2450 - accuracy: 0.3634 - val_loss: 0.2427 - val_accuracy: 0.3400 - lr: 0.0010
# Epoch 4/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.4224
# Epoch 4: val_loss did not improve from 0.24267
# 147/147 [==============================] - 22s 147ms/step - loss: 0.2304 - accuracy: 0.4224 - val_loss: 0.2499 - val_accuracy: 0.4200 - lr: 0.0010
# Epoch 5/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.4451
# Epoch 5: val_loss improved from 0.24267 to 0.24119, saving model to cats.hdf5
# 147/147 [==============================] - 33s 223ms/step - loss: 0.2243 - accuracy: 0.4451 - val_loss: 0.2412 - val_accuracy: 0.5600 - lr: 0.0010
# Epoch 6/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.4805
# Epoch 6: val_loss did not improve from 0.24119
# 147/147 [==============================] - 22s 152ms/step - loss: 0.2164 - accuracy: 0.4805 - val_loss: 0.4301 - val_accuracy: 0.3800 - lr: 0.0010
# Epoch 7/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.5083
# Epoch 7: val_loss improved from 0.24119 to 0.21783, saving model to cats.hdf5
# 147/147 [==============================] - 27s 180ms/step - loss: 0.2046 - accuracy: 0.5083 - val_loss: 0.2178 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 8/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.5477
# Epoch 8: val_loss did not improve from 0.21783
# 147/147 [==============================] - 21s 144ms/step - loss: 0.1949 - accuracy: 0.5477 - val_loss: 0.2718 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 9/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.5605
# Epoch 9: val_loss improved from 0.21783 to 0.21339, saving model to cats.hdf5
# 147/147 [==============================] - 30s 206ms/step - loss: 0.1881 - accuracy: 0.5605 - val_loss: 0.2134 - val_accuracy: 0.5200 - lr: 0.0010
# Epoch 10/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.5755
# Epoch 10: val_loss did not improve from 0.21339
# 147/147 [==============================] - 23s 153ms/step - loss: 0.1841 - accuracy: 0.5755 - val_loss: 0.2610 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 11/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.6289
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 11: val_loss did not improve from 0.21339
# 147/147 [==============================] - 21s 145ms/step - loss: 0.1677 - accuracy: 0.6289 - val_loss: 0.5288 - val_accuracy: 0.4400 - lr: 0.0010
# Epoch 12/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.6789
# Epoch 12: val_loss did not improve from 0.21339
# 147/147 [==============================] - 21s 145ms/step - loss: 0.1466 - accuracy: 0.6789 - val_loss: 0.5673 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 13/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.7050
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 13: val_loss did not improve from 0.21339
# 147/147 [==============================] - 22s 147ms/step - loss: 0.1379 - accuracy: 0.7050 - val_loss: 0.5077 - val_accuracy: 0.5200 - lr: 1.0000e-04
# Epoch 14/30
# 147/147 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.7183
# Epoch 14: val_loss did not improve from 0.21339
# Restoring model weights from the end of the best epoch: 9.
# 147/147 [==============================] - 22s 150ms/step - loss: 0.1306 - accuracy: 0.7183 - val_loss: 0.6775 - val_accuracy: 0.5600 - lr: 1.0000e-05
# Epoch 14: early stopping

# %%
# summarize history for accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim([0,1])
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Actividad 1
#
# Entrene nuevamente el modelo Inception V3 utilizando aumento de datos y compruebe la diferencia en el entrenamiento.

# %%
model_with_aug = Model(pre_trained_model_transfer.input, x)

model_with_aug.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

hist_with_aug = model_with_aug.fit(train_cat_aug,
          epochs = 30,
          validation_data = val_cat,
          callbacks=get_callbacks())
# Out:
# Epoch 1/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.2912
# Epoch 1: val_loss improved from inf to 96.80274, saving model to cats.hdf5
# 147/147 [==============================] - 88s 349ms/step - loss: 0.2709 - accuracy: 0.2912 - val_loss: 96.8027 - val_accuracy: 0.3000 - lr: 0.0010
# Epoch 2/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.3159
# Epoch 2: val_loss improved from 96.80274 to 1.44684, saving model to cats.hdf5
# 147/147 [==============================] - 44s 298ms/step - loss: 0.2604 - accuracy: 0.3159 - val_loss: 1.4468 - val_accuracy: 0.3200 - lr: 0.0010
# Epoch 3/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2577 - accuracy: 0.3185
# Epoch 3: val_loss improved from 1.44684 to 0.28920, saving model to cats.hdf5
# 147/147 [==============================] - 48s 327ms/step - loss: 0.2577 - accuracy: 0.3185 - val_loss: 0.2892 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 4/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.3100
# Epoch 4: val_loss did not improve from 0.28920
# 147/147 [==============================] - 36s 244ms/step - loss: 0.2618 - accuracy: 0.3100 - val_loss: 13.5930 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 5/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.3091
# Epoch 5: val_loss improved from 0.28920 to 0.21728, saving model to cats.hdf5
# 147/147 [==============================] - 47s 322ms/step - loss: 0.2568 - accuracy: 0.3091 - val_loss: 0.2173 - val_accuracy: 0.4200 - lr: 0.0010
# Epoch 6/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.3249
# Epoch 6: val_loss did not improve from 0.21728
# 147/147 [==============================] - 38s 257ms/step - loss: 0.2527 - accuracy: 0.3249 - val_loss: 292.7763 - val_accuracy: 0.1600 - lr: 0.0010
# Epoch 7/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.3313
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 7: val_loss did not improve from 0.21728
# 147/147 [==============================] - 36s 244ms/step - loss: 0.2508 - accuracy: 0.3313 - val_loss: 13.5838 - val_accuracy: 0.2400 - lr: 0.0010
# Epoch 8/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.3707
# Epoch 8: val_loss did not improve from 0.21728
# 147/147 [==============================] - 36s 244ms/step - loss: 0.2390 - accuracy: 0.3707 - val_loss: 0.9637 - val_accuracy: 0.3000 - lr: 1.0000e-04
# Epoch 9/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.3805
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 9: val_loss did not improve from 0.21728
# 147/147 [==============================] - 43s 290ms/step - loss: 0.2341 - accuracy: 0.3805 - val_loss: 0.6115 - val_accuracy: 0.3600 - lr: 1.0000e-04
# Epoch 10/30
# 147/147 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.3920
# Epoch 10: val_loss did not improve from 0.21728
# Restoring model weights from the end of the best epoch: 5.
# 147/147 [==============================] - 38s 256ms/step - loss: 0.2314 - accuracy: 0.3920 - val_loss: 0.4169 - val_accuracy: 0.3800 - lr: 1.0000e-05
# Epoch 10: early stopping

# %%
# summarize history for accuracy
plt.plot(hist_with_aug.history['accuracy'])
plt.plot(hist_with_aug.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(hist_with_aug.history['loss'])
plt.plot(hist_with_aug.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim([0,1])
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Observemos las imágenes con Data Augmentation

plt.figure(figsize=(10,8))
batch = train_cat_aug.next()
#Plots our figures
for i in range(1,17):
  plt.subplot(4, 4, i)
  image_ = batch[0][i-1,:,:,:]
  plt.imshow(image_)
plt.show()

# %% [markdown]
# ## Segmentación con U-Net

# %%
# Obtenemos el conjunto de datos de entrenamiento y prueba
# !gdown 1M2dru41aniQR3fKXrNxd3cXfYd6J1Lvl -O stage1_test.zip
# !gdown 1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR -O stage1_train.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M2dru41aniQR3fKXrNxd3cXfYd6J1Lvl
# To: /content/stage1_test.zip
# 100% 9.55M/9.55M [00:00<00:00, 47.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1O7ZZvA2Co8PCi3XnLV71n0GUWx-5MmvR
# To: /content/stage1_train.zip
# 100% 82.9M/82.9M [00:01<00:00, 54.0MB/s]

# %%
# Descomprimimos los conjuntos de datos.
# !unzip -q stage1_train.zip -d stage1_train/
# !unzip -q stage1_test.zip -d stage1_test/

# %%
IMG_WIDTH = 128 # Ancho en el que se redimensionarán las imágenes.
IMG_HEIGHT = 128 # Alto en el que se redimensionarán las imágenes.
IMG_CHANNELS = 3 # Canales de color que tienen las imágenes (rojo, verde y azul)
TRAIN_PATH = 'stage1_train/' # Ubicación del conjunto de datos de entrenamiento.
TEST_PATH = 'stage1_test/' # Ubicación del conjunto de datos de prueba.

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

# Establecemos una semilla para la generación de datos aleatorios
seed = 11 
random.seed = seed
np.random.seed = seed

# %%
# Obtenemos los nombres de las imágenes de entrenamiento y prueba
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
# Redimensionamos todas las imágenes
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# <ipython-input-20-38464d2cb465>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
#   0%|          | 0/670 [00:00<?, ?it/s]<ipython-input-20-38464d2cb465>:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
# 100%|██████████| 670/670 [04:55<00:00,  2.26it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:01<00:00, 48.53it/s]
# Done!

# %%
# Verificamos la imagen cruda y la máscara de segmentación de una imagen al azar.
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# U-Net es una arquitectura especializada para la segmentación de imágenes biomédicas https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/ .
#
# Esta arquitectura utiliza una serie de capas de convolución para realizar las predicciones y el esquema es el siguiente:
#
# ![U-Net Architecture](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
# Esta es la implementación en TensorFlow de U-Net

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s) # Capa convolucional
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.MeanIoU(2)])
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  lambda (Lambda)                (None, 128, 128, 3)  0           ['input_3[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 128, 128, 16  448         ['lambda[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 16  0           ['conv2d_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_1[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 16)  0           ['conv2d_189[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 64, 64, 32)   4640        ['max_pooling2d_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_2[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 32, 32, 64)   18496       ['max_pooling2d_9[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_192[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_3[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_193[0][0]']
#  )
#
#  conv2d_194 (Conv2D)            (None, 16, 16, 128)  73856       ['max_pooling2d_10[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_194[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_4[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 128)   0           ['conv2d_195[0][0]']
#  )
#
#  conv2d_196 (Conv2D)            (None, 8, 8, 256)    295168      ['max_pooling2d_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 8, 8, 256)    590080      ['dropout_5[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_197[0][0]']
#  ose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_195[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 16, 16, 128)  295040      ['concatenate_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_198[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 16, 16, 128)  147584      ['dropout_6[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  32832       ['conv2d_199[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_193[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 32, 32, 64)   73792       ['concatenate_5[0][0]']
#
#  dropout_7 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 32, 32, 64)   36928       ['dropout_7[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  8224        ['conv2d_201[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_191[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 64, 64, 32)   18464       ['concatenate_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_202[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 64, 64, 32)   9248        ['dropout_8[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_203[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_189[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 128, 128, 16  4624        ['concatenate_7[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 128, 128, 16  0           ['conv2d_204[0][0]']
#                                 )
#
#  conv2d_205 (Conv2D)            (None, 128, 128, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  conv2d_206 (Conv2D)            (None, 128, 128, 1)  17          ['conv2d_205[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# La arquitectura cuenta con alrededor de 2 millones de parámetros que serán entrenados.

# %%
# Entrenamiento del modelo

earlystopper = EarlyStopping(patience=5, verbose=1)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=50, 
                    callbacks=[earlystopper])
# Out:
# Epoch 1/50
# 38/38 [==============================] - 17s 148ms/step - loss: 0.4191 - mean_io_u: 0.3758 - val_loss: 0.2878 - val_mean_io_u: 0.3771
# Epoch 2/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1977 - mean_io_u: 0.3758 - val_loss: 0.1597 - val_mean_io_u: 0.3771
# Epoch 3/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1741 - mean_io_u: 0.3758 - val_loss: 0.1424 - val_mean_io_u: 0.3771
# Epoch 4/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1455 - mean_io_u: 0.3758 - val_loss: 0.1620 - val_mean_io_u: 0.3771
# Epoch 5/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1377 - mean_io_u: 0.3758 - val_loss: 0.1416 - val_mean_io_u: 0.3771
# Epoch 6/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1238 - mean_io_u: 0.3758 - val_loss: 0.1180 - val_mean_io_u: 0.3771
# Epoch 7/50
# 38/38 [==============================] - 2s 55ms/step - loss: 0.1203 - mean_io_u: 0.3758 - val_loss: 0.1340 - val_mean_io_u: 0.3771
# Epoch 8/50
# 38/38 [==============================] - 2s 54ms/step - loss: 0.1148 - mean_io_u: 0.3758 - val_loss: 0.1153 - val_mean_io_u: 0.3771
# Epoch 9/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1072 - mean_io_u: 0.3758 - val_loss: 0.1137 - val_mean_io_u: 0.3771
# Epoch 10/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1045 - mean_io_u: 0.3758 - val_loss: 0.1052 - val_mean_io_u: 0.3771
# Epoch 11/50
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0984 - mean_io_u: 0.3758 - val_loss: 0.1087 - val_mean_io_u: 0.3771
# Epoch 12/50
# 38/38 [==============================] - 2s 51ms/step - loss: 0.1011 - mean_io_u: 0.3758 - val_loss: 0.1090 - val_mean_io_u: 0.3771
# Epoch 13/50
# 38/38 [==============================] - 2s 55ms/step - loss: 0.0965 - mean_io_u: 0.3758 - val_loss: 0.1071 - val_mean_io_u: 0.3771
# Epoch 14/50
# 38/38 [==============================] - 2s 52ms/step - loss: 0.0929 - mean_io_u: 0.3758 - val_loss: 0.1099 - val_mean_io_u: 0.3771
# Epoch 15/50
# 38/38 [==============================] - 2s 54ms/step - loss: 0.0952 - mean_io_u: 0.3758 - val_loss: 0.1073 - val_mean_io_u: 0.3771
# Epoch 15: early stopping

# %%
# Predicción sobre los datos de entrenamiento, validación y prueba

preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 19/19 [==============================] - 3s 68ms/step
# 3/3 [==============================] - 0s 23ms/step
# 3/3 [==============================] - 0s 197ms/step

# %%
# Visualizamos unas predicciones al azar sobre el conjunto de entrenamiento
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
# Visualizamos unas predicciones al azar sobre el conjunto de validación

ix = random.randint(0, len(preds_val_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_val_t[ix]))
plt.show()

# %% [markdown]
# ## Actividad 2
#
# Visualiza la salida de la según fase de convoluciones en downscaling (c2) y la penúltima capa de upscaling (c8). Puedes utilizar las funciones de la clase anterior.

# %%
layer_names = [layer.name for layer in model.layers]
activations = list(zip(layer_names, preds_test))

# %%
plt.title(activations[8][0])
plt.imshow(activations[8][1], cmap="viridis")
plt.show()

# %%
plt.title(activations[-7][0])
plt.imshow(activations[-7][1], cmap="viridis")
plt.show()
